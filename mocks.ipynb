# %%
import h5py

# %%
base = '/global/cfs/projectdirs/desi/mocks/cai/abacus_HF/DR2_v2.0/AbacusSummit_base_c000_ph000/Boxes/BGS-21.35'

# %%
filename = f'{base}/abacus_HF_BGS-21.35_0p300_DR2_v2.0_AbacusSummit_base_c000_ph000_base_clustering.dat.h5'

# %%
with h5py.File(filename, "r") as f:
    print("Keys:", list(f.keys()))

    def print_structure(name, obj):
        print(name, type(obj))

    f.visititems(print_structure)
# Out:
# Keys: ['HALO_ID', 'ISCENTRAL', 'MASS', 'VSMEAR', 'VX', 'VY', 'VZ', 'X', 'Y', 'Z']
# HALO_ID <class 'h5py._hl.dataset.Dataset'>
# ISCENTRAL <class 'h5py._hl.dataset.Dataset'>
# MASS <class 'h5py._hl.dataset.Dataset'>
# VSMEAR <class 'h5py._hl.dataset.Dataset'>
# VX <class 'h5py._hl.dataset.Dataset'>
# VY <class 'h5py._hl.dataset.Dataset'>
# VZ <class 'h5py._hl.dataset.Dataset'>
# X <class 'h5py._hl.dataset.Dataset'>
# Y <class 'h5py._hl.dataset.Dataset'>
# Z <class 'h5py._hl.dataset.Dataset'>
